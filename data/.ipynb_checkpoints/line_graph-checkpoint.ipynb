# %%
library(tidyverse)
library(dplyr)
library(ggplot2)
# Out:
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.2.1 ──
# ✔ ggplot2 3.2.1     ✔ purrr   0.3.3
# ✔ tibble  2.1.3     ✔ dplyr   0.8.3
# ✔ tidyr   1.0.0     ✔ stringr 1.4.0
# ✔ readr   1.3.1     ✔ forcats 0.4.0
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()

# %%
factors_data=read.csv("clean_data_line_plot.csv")
factors_data$obesity <- factors_data$obesity / 1000000

# %%
line_plot <- ggplot(factors_data, aes(x= year, y = obesity, color=continent)) +
  geom_line(size=0.5, shape=10, fill="green")+
geom_point()+
  xlab("Years") +
  ylab("Number of Deaths (millions)")+
   scale_x_continuous(breaks = seq(1990, 2020, 1))+
theme(axis.text.x = element_text(angle = -60, hjust = 0))+

    ggtitle("Number of Deaths over the years in continents")


 line_plot
# Out:
# Warning message:
# “Ignoring unknown parameters: shape, fill”
# plot without title

# %%
line_plt<-function(factors_data,var){


line_plot <- ggplot(factors_data, aes(x= year, y = var, color=continent)) +
  geom_line(size=0.5, shape=10, fill="green")+
geom_point()+
  xlab("Years") +
  ylab("Number of Deaths (millions)")+
   scale_x_continuous(breaks = seq(1990, 2020, 1))+
theme(axis.text.x = element_text(angle = -60, hjust = 0))+

    ggtitle("Number of Deaths over the years in continents")


      return(line_plot)
}

# %%
line_plt(factors_data, "obesity")
# Out:
# Warning message:
# “Ignoring unknown parameters: shape, fill”
# plot without title
